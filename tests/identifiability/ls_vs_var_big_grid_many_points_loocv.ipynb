# %% [markdown]
# # Sandbox - Likelihood
#
# This notebook is used to prototype the likelihood function, used to generate all scenarios of use of the algorithm.

# %% [markdown]
# ---

# %% [markdown]
# ## Imports & Config

# %%
import matplotlib.pyplot as plt
! pwd
# Out:
# /Users/simonlejoly/Documents/Work/mimosa/tests/identifiability

# %%
! export XLA_PYTHON_CLIENT_MEM_FRACTION=.25

# %%
# Jax configuration
USE_JIT = True
USE_X64 = True
DEBUG_NANS = False
VERBOSE = False

# %%
# Standard library imports
import os
os.environ['JAX_ENABLE_X64'] = str(USE_X64).lower()

import logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
# Third party
import jax
jax.config.update("jax_disable_jit", not USE_JIT)
jax.config.update("jax_debug_nans", DEBUG_NANS)
import jax.random as jr
import jax.numpy as jnp
from jax import vmap, jit, Array, grad

import plotly.graph_objects as go
from plotly.subplots import make_subplots

import numpy as np

from kernax import ZeroMean, ConstantMean, LinearMean, AffineMean, AbstractMean, AbstractKernel
from kernax import SEKernel, VarianceKernel, sample_hps_from_uniform_priors, BatchModule, config
#config.parameter_transform = "exp"

# %%
# Local imports
from mimosa.sampling import sample_gp
#from likelihood_comps import *
# Out:
# INFO:2026-03-09 09:51:28,991:jax._src.xla_bridge:834: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/mimosa/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)
# 2026-03-09 09:51:28,991 - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/miniconda3/envs/mimosa/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file)

# %%
key = jr.PRNGKey(42)

# %% [markdown]
# ---

# %% [markdown]
# ## LOO-CV

# %%
from mimosa.linalg import cho_factor, cho_solve

def loo_cv(inputs: Array, outputs: Array, mean: AbstractMean, kern: AbstractKernel, jitter: Array = jnp.array(1e-6)) -> Array:
	"""
	Compute the leave-one-out cross-validation log probability for a Gaussian Process.

	Args:
		inputs (Array): The input data points, shape (N, I)
		outputs (Array): The observed output values, shape (N,).
		mean (AbstractMean): The mean function of the GP.
		kern (AbstractKernel): The kernel function of the GP.
		jitter (float): A small value added to the diagonal of the covariance matrix for numerical stability.

	Returns:
		Array: An array of shape (N,) containing the LOO-CV for each data point.
	"""
	m = mean(inputs)  # Shape (N,)
	cov = kern(inputs)  # Shape (N, N)

	# Invert cov matrix
	prec = cho_solve(cho_factor(cov + jitter * jnp.eye(len(inputs))), jnp.eye(len(inputs)))

	mus = outputs - (prec @ (outputs - m)) / jnp.diag(prec)
	sigmas = 1 / jnp.diag(prec)

	loo_cv_values = -0.5 * jnp.log(2 * jnp.pi) - 0.5 * ((outputs - mus)**2 / sigmas) - 0.5 * jnp.log(sigmas)

	return loo_cv_values

# %%
def full_loo_cv(inputs: Array, outputs: Array, mean: AbstractMean, kern: AbstractKernel, jitter: Array = jnp.array(1e-6)) -> Array:
	"""
	Compute the full leave-one-out cross-validation log probability for a Gaussian Process.

	Args:
		inputs (Array): The input data points, shape (N, I)
		outputs (Array): The observed output values, shape (N,).
		mean (AbstractMean): The mean function of the GP.
		kern (AbstractKernel): The kernel function of the GP.
		jitter (float): A small value added to the diagonal of the covariance matrix for numerical stability.

	Returns:
		Array: The total LOO-CV log probability across all data points.
	"""
	return -jnp.sum(loo_cv(inputs, outputs, mean, kern, jitter))

# %% [markdown]
# ---

# %% [markdown]
# ## GP identifiability - SE without noise

# %%
sample_jitter = jnp.array(1e-10)
loo_cv_jitter = jnp.array(1e-3)

# %%
grid_range = (-25, 25)
nb_points = 200
grid = jnp.linspace(*grid_range, nb_points)[:, None]

# %%
kern_priors = {"variance":(1., 5.), "length_scale": (.5, 2.)}

# %% [markdown]
# ### 1 sample

# %%
kern = VarianceKernel(variance=1.) * SEKernel(length_scale=1.)
key, subkey = jr.split(key)
kern = sample_hps_from_uniform_priors(subkey, kern, kern_priors)
mean = ZeroMean()
print(f"{kern}\n{mean}")
# Out:
# VarianceKernel(variance=3.20) * SEKernel(length_scale=1.13)
#         1.42327331e+00,  9.18382989e-01,  5.28115734e-01,  1.68608506e-01,
#        -2.59074136e-01, -7.85841354e-01, -1.34284169e+00, -1.79500383e+00,
#        -2.01633983e+00, -1.96241620e+00, -1.69991474e+00, -1.37699557e+00,
#        -1.14993877e+00, -1.10669154e+00, -1.22921333e+00, -1.41230918e+00,
#        -1.52130756e+00, -1.45159989e+00, -1.15944993e+00, -6.59204615e-01,
#        -3.55064387e-03,  7.31493289e-01,  1.44913623e+00,  2.03214756e+00,
#         2.35814362e+00,  2.33616078e+00,  1.95026163e+00,  1.28352140e+00,
#         5.00675702e-01, -2.06620652e-01, -6.87107150e-01, -8.76247991e-01,
#        -8.01152800e-01, -5.48028365e-01, -2.13585594e-01,  1.30708993e-01,
#         4.48299605e-01,  7.23536447e-01,  9.43227329e-01,  1.08940755e+00,
#         1.14788646e+00,  1.12277516e+00,  1.04364012e+00,  9.57518629e-01,
#         9.09784963e-01,  9.24050585e-01,  9.91086401e-01,  1.07105322e+00,
#         1.10917692e+00,  1.05972284e+00,  9.09729384e-01,  6.89770393e-01])

# %%
# Plot the sample
plt.scatter(grid, vals, marker=".")
plt.xlim(*map(lambda x: x*1.1, grid_range))
plt.ylim(-max(kern_priors["variance"])*1.5, max(kern_priors["variance"])*1.5)
plt.show()

# %%
emp_var = jnp.mean((vals - mean(grid))**2)  # Variance around true mean
emp_var
# Out:
# Array(3.51432871, dtype=float64)

# %%
jnp.var(vals)  # Variance around empirical mean
# Out:
# Array(3.43956453, dtype=float64)

# %%
lss = jnp.exp(jnp.linspace(jnp.log(0.1), jnp.log(2.5), 100))
vrs = jnp.exp(jnp.linspace(jnp.log(0.75), jnp.log(7.0), 100))

# %%
loo_cv_from_hps = jit(lambda l, v: full_loo_cv(grid, vals, mean, (VarianceKernel(variance=v) * SEKernel(length_scale=l)), jitter=loo_cv_jitter).squeeze())

# %%
loo_cv_values = vmap(vmap(loo_cv_from_hps, in_axes=(0, None)), in_axes=(None, 0))(lss, vrs)
loo_cv_grads =  vmap(vmap(grad(loo_cv_from_hps, argnums=(0, 1)), in_axes=(0, None)), in_axes=(None, 0))(lss, vrs)
loo_cv_values.shape, loo_cv_grads[0].shape,  loo_cv_grads[1].shape
# Out:
# ((100, 100), (100, 100), (100, 100))

# %%
orig_var = kern.left.variance.item()
orig_ls = kern.right.length_scale.item()
v_opt, l_opt = jnp.unravel_index(jnp.argmin(loo_cv_values), loo_cv_values.shape)

# %%
orig_ls, lss[l_opt].item(), orig_var, vrs[v_opt].item(), emp_var.item()
# Out:
# (1.1309826013678217,
#  1.1456328578240764,
#  3.195029507840844,
#  6.999999999999999,
#  3.514328708403951)

# %%
loo_cv_values[v_opt, l_opt]
# Out:
# Array(-460.36896499, dtype=float64)

# %%
fig = make_subplots(
    rows=1, cols=3,
    subplot_titles=['LOO-VC values', 'length_scale grads', 'variance grads'],
    specs=[[{'type': 'surface'}, {'type': 'surface'}, {'type': 'surface'}],],
    horizontal_spacing=0.05,
    vertical_spacing=0.1,
)

# --- VALUES ---

fig.add_trace(go.Surface(x=lss, y=vrs, z=np.asarray(loo_cv_values), showscale=False, colorscale='Viridis'), row=1, col=1)

fig.add_trace(go.Scatter3d(
    x=[orig_ls], y=[orig_var], z=[loo_cv_from_hps(orig_ls, orig_var)],
    mode='markers', marker=dict(size=6, color='red'),
    showlegend=False,
), row=1, col=1)

fig.add_trace(go.Scatter3d(
    x=[lss[l_opt].item()], y=[vrs[v_opt].item()], z=[loo_cv_values[v_opt, l_opt].item()],
    mode='markers', marker=dict(size=6, color='green'),
    name=f'Kernel optimal (var={vrs[v_opt].item():.2f}, ls={lss[l_opt].item():.2f})',
    showlegend=False,
), row=1, col=1)

# --- GRADS (ls) ---

fig.add_trace(go.Surface(x=lss, y=vrs, z=np.asarray(loo_cv_grads[0]), showscale=False, colorscale='Viridis'), row=1, col=2)

fig.add_trace(go.Surface(x=lss, y=vrs, z=np.asarray(jnp.zeros_like(loo_cv_grads[0])), showscale=False, colorscale='Viridis'), row=1, col=2)

fig.add_trace(go.Scatter3d(
    x=[orig_ls], y=[orig_var], z=[grad(loo_cv_from_hps, argnums=(0, 1))(orig_ls, orig_var)[0]],
    mode='markers', marker=dict(size=6, color='red'),
    showlegend=False,
), row=1, col=2)

fig.add_trace(go.Scatter3d(
    x=[lss[l_opt].item()], y=[vrs[v_opt].item()], z=[loo_cv_grads[0][v_opt, l_opt].item()],
    mode='markers', marker=dict(size=6, color='green'),
    name=f'Kernel optimal (var={vrs[v_opt].item():.2f}, ls={lss[l_opt].item():.2f})',
    showlegend=False,
), row=1, col=2)

# --- GRADS (var) ---

fig.add_trace(go.Surface(x=lss, y=vrs, z=np.asarray(loo_cv_grads[1]), showscale=False, colorscale='Viridis'), row=1, col=3)

fig.add_trace(go.Surface(x=lss, y=vrs, z=np.asarray(jnp.zeros_like(loo_cv_grads[1])), showscale=False, colorscale='Viridis'), row=1, col=3)

fig.add_trace(go.Scatter3d(
    x=[orig_ls], y=[orig_var], z=[grad(loo_cv_from_hps, argnums=(0, 1))(orig_ls, orig_var)[1]],
    mode='markers', marker=dict(size=6, color='red'),
    showlegend=False,
), row=1, col=3)

fig.add_trace(go.Scatter3d(
    x=[lss[l_opt].item()], y=[vrs[v_opt].item()], z=[loo_cv_grads[1][v_opt, l_opt].item()],
    mode='markers', marker=dict(size=6, color='green'),
    name=f'Kernel optimal (var={vrs[v_opt].item():.2f}, ls={lss[l_opt].item():.2f})',
    showlegend=False,
), row=1, col=3)

fig.update_layout(
    title='NLL values and grads',
    scene =dict(xaxis_title='length_scale', yaxis_title='variance', zaxis_title='NLL values', xaxis_autorange='reversed', yaxis_autorange='reversed'),
    scene2=dict(xaxis_title='length_scale', yaxis_title='variance', zaxis_title='NLL grads - length-scale', xaxis_autorange='reversed', yaxis_autorange='reversed'),
    scene3=dict(xaxis_title='length_scale', yaxis_title='variance', zaxis_title='NLL grads - variance', xaxis_autorange='reversed', yaxis_autorange='reversed'),
	height=700
)

fig.show()

# %% [markdown]
# ### Multi-sample

# %%
nb_samples = 1000
key, subkey_1, subkey_2 = jr.split(key, 3)

# %%
kern = VarianceKernel(variance=1.) * SEKernel(length_scale=1.)
kern = BatchModule(kern, batch_size=nb_samples, batch_in_axes=0, batch_over_inputs=False)  # Distinct HPs in each kernel
kern = sample_hps_from_uniform_priors(subkey_1, kern, kern_priors)
mean = ZeroMean()
print(f"{kern}\n{mean}")
# Out:
# VarianceKernel(variance=[3.03 ± 1.15]₁₀₀₀) * SEKernel(length_scale=[1.24 ± 0.44]₁₀₀₀)
# ZeroMean()

# %%
subkeys = jr.split(subkey_2, nb_samples)
samples = vmap(lambda k, cov: sample_gp(k, mean(grid), cov, jitter=sample_jitter))(subkeys, kern(grid))
samples.shape
# Out:
# (1000, 200)

# %%
# Plot the sample
plt.scatter(jnp.broadcast_to(grid.T, samples.shape), samples, marker=".", alpha=0.05)
plt.xlim(*map(lambda x: x*1.1, grid_range))
plt.ylim(-max(kern_priors["variance"])*1.5, max(kern_priors["variance"])*1.5)
plt.show()

# %%
full_emp_var = jnp.mean(jnp.mean((samples - mean(grid)[None, :])**2, axis=1))  # Full variance around original mean
full_emp_var
# Out:
# Array(3.00285035, dtype=float64)

# %%
jnp.var(samples)  # Full variance around empirical mean
# Out:
# Array(3.00285032, dtype=float64)

# %%
samples.shape, mean(grid).shape
# Out:
# ((1000, 200), (200,))

# %%
loo_cv_from_hps = jit(lambda s, l, v: full_loo_cv(grid, s, mean, (VarianceKernel(variance=v) * SEKernel(length_scale=l)), jitter=loo_cv_jitter).squeeze())

# %%
loo_cv_values = jit(vmap(lambda s: vmap(vmap(loo_cv_from_hps, in_axes=(None, 0, None)), in_axes=(None, None, 0))(s, lss, vrs)))(samples)
loo_cv_values.shape
# Out:
# (1000, 100, 100)

# %%
v_opt, l_opt = vmap(lambda lvs: jnp.unravel_index(jnp.argmin(lvs), lvs.shape))(loo_cv_values)
v_opt.shape, l_opt.shape
# Out:
# ((1000,), (1000,))

# %%
opti_lss = lss[l_opt]
orig_lss = kern.inner.right.length_scale
opti_lss.shape, orig_lss.shape
# Out:
# ((1000,), (1000,))

# %%
opti_vars = vrs[v_opt]
orig_vars = kern.inner.left.variance
empi_vars = jnp.mean((samples - mean(grid)[None, :])**2, axis=1)
opti_vars.shape, orig_vars.shape, empi_vars.shape
# Out:
# ((1000,), (1000,), (1000,))

# %%
fig, ax = plt.subplots(1, 5, figsize=(15, 4))

ax[0].hist(orig_lss, bins=50)
ax[0].set_title("Original length-scales")
ax[0].set_xlim(kern_priors["length_scale"][0]-.25, kern_priors["length_scale"][-1]+.25)
ax[0].set_ylim(0, 100)

ax[1].hist(opti_lss, bins=50)
ax[1].set_title("Optimal length-scales")
ax[1].set_xlim(kern_priors["length_scale"][0]-.25, kern_priors["length_scale"][-1]+.25)
ax[1].set_ylim(0, 100)

ax[2].hist(orig_vars, bins=50)
ax[2].set_title("Original variances")
ax[2].set_xlim(0., 8.)
ax[2].set_ylim(0, 100)

ax[3].hist(opti_vars, bins=50)
ax[3].set_title("Optimal variances")
ax[3].set_xlim(0., 8.)
ax[3].set_ylim(0, 100)

ax[4].hist(empi_vars, bins=50)
ax[4].set_title("Empirical variances")
ax[4].set_xlim(0., 8.)
ax[4].set_ylim(0, 100)


plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 4))

nb_bins = 100
ls_low, ls_high = -.5, .5
vr_low, vr_high = -7, 7
ls_bins = jnp.linspace(ls_low, ls_high, nb_bins)
var_bins = jnp.linspace(vr_low, vr_high, nb_bins)
ls_max = 250
var_max = 100

ax[0].hist(opti_lss - orig_lss, bins=ls_bins)
ax[0].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[0].set_title("Optimal-Original length-scales")
ax[0].set_xlim(ls_low, ls_high)
ax[0].set_ylim(0, 100)

ax[1].hist(opti_vars - orig_vars, bins=var_bins)
ax[1].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[1].set_title("Optimal-Original variances")
ax[1].set_xlim(vr_low, vr_high)
ax[1].set_ylim(0, 100)

ax[2].hist(opti_vars - empi_vars, bins=var_bins)
ax[2].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[2].set_title("Optimal-Empirical variances")
ax[2].set_xlim(vr_low, vr_high)
ax[2].set_ylim(0, 100)

ax[3].hist(empi_vars - orig_vars, bins=var_bins)
ax[3].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[3].set_title("Empirical-Original variances")
ax[3].set_xlim(vr_low, vr_high)
ax[3].set_ylim(0, 100)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 4))

low, high = -200, 200
bins = jnp.linspace(low, high, 100)
ls_max = 250
var_max = 100

ax[0].hist((opti_lss - orig_lss)/orig_lss*100, bins=bins)
ax[0].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[0].set_title("Optimal-Original length-scales")
ax[0].set_xlim(low, high)
ax[0].set_ylim(0, ls_max)

ax[1].hist((opti_vars - orig_vars)/orig_vars*100, bins=bins)
ax[1].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[1].set_title("Optimal-Original variances")
ax[1].set_xlim(low, high)
ax[1].set_ylim(0, var_max)

ax[2].hist((opti_vars - empi_vars)/empi_vars*100, bins=bins)
ax[2].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[2].set_title("Optimal-Empirical variances")
ax[2].set_xlim(low, high)
ax[2].set_ylim(0, var_max)

ax[3].hist((empi_vars - orig_vars)/orig_vars*100, bins=bins)
ax[3].axvline(0, color='red', linestyle='--', label='Ground truth')
ax[3].set_title("Empirical-Original variances")
ax[3].set_xlim(low, high)
ax[3].set_ylim(0, var_max)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
